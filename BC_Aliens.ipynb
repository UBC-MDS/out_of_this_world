# %%
import pandas as pd
import numpy as np

# %%
bc_aliens = pd.read_html('http://www.nuforc.org/webreports/ndxlBC.html')

# %%
sightings_df = bc_aliens[0]

# %%
sightings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date / Time  533 non-null    object
#  1   City         534 non-null    object
#  2   State        534 non-null    object
#  3   Shape        513 non-null    object
#  4   Duration     521 non-null    object
#  5   Summary      534 non-null    object
#  6   Posted       534 non-null    object
# dtypes: object(7)
# memory usage: 29.3+ KB

# %%
pd.DataFrame(np.array(bc_aliens).reshape(534, 7))
# Out:
#                    0                         1   2          3            4  \
# 0      10/3/20 00:38          Kelowna (Canada)  BC    Chevron    2 minutes
# 1      9/20/20 22:00        Vancouver (Canada)  BC      Light       1 hour
# 2      9/16/20 18:30  North Vancouver (Canada)  BC      Other    5 minutes
# 3      8/16/20 04:12    Prince George (Canada)  BC      Light  2-3 minutes
# 4      8/14/20 00:00          Merritt (Canada)  BC  Formation   30 seconds
# ..               ...                       ...  ..        ...          ...
# 529    4/10/57 00:15           Vernon (Canada)  BC      Light  still there
# 530            22:20        Vancouver (Canada)  BC      Light    5 minutes
# 531  12 months 13:00      Fort Nelson (Canada)  BC   Changing   45 minutes
# 532   12092019 05:30                Chilliwack  BC     Circle       15mins
# 533              NaN          Kelowna (Canada)  BC        NaN          NaN
#
#                                                      5         6
# 0    I went out to the backyard to call our cat ins...   11/5/20
# 1                           a small bright orange star   11/5/20
# 2    Two black objects in the shape of an infinity ...   11/5/20
# 3    satellite traveling from West to East. Then I ...   8/20/20
# 4    3 this am about 15 to20 objects flew from west...   8/20/20
# ..                                                 ...       ...
# 529  two white lights one red. stationary for sever...   2/13/20
# 530  Lights appear in sequence and disappear before...    6/7/19
# 531          Object was bright lit and changed shapes.    9/9/13
# 532  Multiple lights falling in a direct line.Looki...  12/19/19
# 533  They were close to my home, hope they come soo...    7/3/13
#
# [534 rows x 7 columns]
